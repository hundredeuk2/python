# %%
import pandas as pd
import numpy as np
import os

# os.chdir("C://Users//BIS_COM//data//train//Sejong")
os.chdir("/Users/patricklee/Desktop/파이썬/compas/sejong/")

# %%
one_df = pd.read_csv('./1.세종시_전유부.csv', encoding="cp949")
two_df = pd.read_csv('./2.세종시_표제부.csv', encoding="cp949")
apart_deal_df = pd.read_csv('./3.세종시_아파트(매매)_실거래가.csv', encoding="cp949")
apart_jeonsae_df= pd.read_csv('./7.세종시_아파트(전월세)_실거래가.csv', encoding="cp949")
bunyang_df= pd.read_csv('./13.세종시_분양권_실거래가.csv', encoding="cp949")
# Out:
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (10,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
one_df.head()
# Out:
#    순번                      대지위치  시군구코드  법정동코드  대지구분코드     번     지 대장구분코드명  \
# 0   1  세종특별자치시  반곡동 4121-1002번지  36110  10100       1  4121  1002      집합
# 1   2  세종특별자치시  반곡동 4121-1002번지  36110  10100       1  4121  1002      집합
# 2   3  세종특별자치시  반곡동 4121-1002번지  36110  10100       1  4121  1002      집합
# 3   4  세종특별자치시  반곡동 4121-1002번지  36110  10100       1  4121  1002      집합
# 4   5  세종특별자치시  반곡동 4121-1002번지  36110  10100       1  4121  1002      집합
#
#      건물명 특수지명   블록   로트      동명칭  호명칭 층구분코드명  층번호
# 0  세종펠리스  NaN  NaN  NaN  주건축물제1동  616     지상    6
# 1  세종펠리스  NaN  NaN  NaN  주건축물제1동  624     지상    6
# 2  세종펠리스  NaN  NaN  NaN  주건축물제1동  523     지상    5
# 3  세종펠리스  NaN  NaN  NaN  주건축물제1동  314     지상    3
# 4  세종펠리스  NaN  NaN  NaN  주건축물제1동  101     지상    1

# %%
two_df.head()
# Out:
#    순번                   대지위치  시군구코드  법정동코드  대지구분코드    번   지 대장구분코드명     건물명  \
# 0   1  세종특별자치시  반곡동 146-75번지  36110  10100       1  146  75      일반     NaN
# 1   2  세종특별자치시  반곡동 146-79번지  36110  10100       1  146  79      일반     NaN
# 2   3  세종특별자치시  반곡동 146-79번지  36110  10100       1  146  79      일반     NaN
# 3   4  세종특별자치시  반곡동 146-79번지  36110  10100       1  146  79      일반     NaN
# 4   5   세종특별자치시  반곡동 180-1번지  36110  10100       1  180   1      일반  솔빛숲유치원
#
#    동명칭   연면적(㎡)     구조코드명    주용도코드명 세대수(세대)       사용승인일  Unnamed: 15
# 0  NaN   135.24      벽돌구조      단독주택       0      1977.0          NaN
# 1   1동      576    강파이프구조  동.식물관련시설       0      1999.0          NaN
# 2   2동      336    강파이프구조  동.식물관련시설       0  20041223.0          NaN
# 3   3동   127.19    강파이프구조      창고시설       0  19950726.0          NaN
# 4  NaN  2697.74  철근콘크리트구조    교육연구시설       0  20190228.0          NaN

# %%
apart_deal_df.head()
# Out:
#      계약년월  계약일          시군구    본번  부번                단지명  전용면적(㎡)  거래금액(만원)  \
# 0  201701    1  세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)  16.9849      8600
# 1  201701    1  세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)  59.8652     27300
# 2  201701    2  세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)  84.9894     32000
# 3  201701    2  세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)  84.9800     30500
# 4  201701    2  세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티  84.9280     31300
#
#     층  건축년도
# 0   7  2016
# 1   7  2014
# 2   3  2015
# 3  20  2015
# 4   6  2014

# %%
apart_jeonsae_df.head()
# Out:
#      계약년월  계약일               시군구    본번  부번                  단지명 전월세구분  \
# 0  201701    1       세종특별자치시 고운동  1409   0    가락마을11단지(중흥에듀카운티)    전세
# 1  201701    1  세종특별자치시 조치원읍 신안리    35   3                  유니빌    전세
# 2  201701    2       세종특별자치시 고운동  1728   0  가락마을6단지(중흥S클래스프라디움)    전세
# 3  201701    2       세종특별자치시 고운동  1728   0  가락마을6단지(중흥S클래스프라디움)    전세
# 4  201701    2       세종특별자치시 고운동  1728   0  가락마을6단지(중흥S클래스프라디움)    전세
#
#    전용면적(㎡)  보증금(만원)  월세(만원)   층  건축년도
# 0  59.9907    16000       0  12  2016
# 1  28.1680     2800       0   6  2002
# 2  59.9942    19475       0  27  2015
# 3  59.7236    19475       0  21  2015
# 4  59.7236    17370       0   2  2015

# %%
bunyang_df.head()
# Out:
#      계약년월  계약일          시군구                   단지명   전용면적(㎡)  거래금액(만원)   층  \
# 0  201701    1  세종특별자치시 다정동  가온마을 1단지 (2-1,힐스테이트)   74.9668     29250   5
# 1  201701    1  세종특별자치시 새롬동       새뜸마을 1단지(메이저시티)  101.8063     39080   3
# 2  201701    1  세종특별자치시 새롬동      새뜸마을 5단지( 메이저시티)  101.8063     42090  12
# 3  201701    2  세종특별자치시 다정동   가온마을 2단지(2-1 한신,제일)   75.5847     29280  17
# 4  201701    2  세종특별자치시 다정동    가온마을 3단지(2-1한신．제일)   97.5713     37767  13
#
#   분/입구분
# 0     분
# 1     분
# 2     분
# 3     분
# 4     분

# %%
bunyang_df['분/입구분'].unique()
# Out:
# array(['분', '입'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.countplot(data=bunyang_df,x="분/입구분")
# Out:
# <AxesSubplot:xlabel='분/입구분', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51077 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
bunyang_df[bunyang_df['분/입구분'] == '입'].count()
# Out:
# 계약년월        14
# 계약일         14
# 시군구         14
# 단지명         14
# 전용면적(㎡)     14
# 거래금액(만원)    14
# 층           14
# 분/입구분       14
# dtype: int64

# %%
plt.figure(figsize=(30,15))
sns.countplot(data=bunyang_df, x='계약년월',hue="시군구")
# Out:
# <AxesSubplot:xlabel='계약년월', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50557 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
come_peo_df = pd.read_csv('./20.세종시_전입자수.csv')
out_peo_df = pd.read_csv('./21.세종시_전출자수.csv')

# %%
come_peo_df.head()
# Out:
#        년월  전입자수 세종전입행정동  전출시 전출시군구 전출읍면동
# 0  201701     1    조치원읍  강원도   강릉시   교1동
# 1  201701     6    조치원읍  강원도   동해시   천곡동
# 2  201701    14    조치원읍  강원도   속초시    교동
# 3  201701    21    조치원읍  강원도   양양군    서면
# 4  201701     2    조치원읍  강원도   원주시   원인동

# %%
out_peo_df.head()
# Out:
#        년월  전출자수 세종전출행정동  전입시    전입시군구 전입읍면동
# 0  201701     3    조치원읍  강원도      원주시   단계동
# 1  201701     9    조치원읍  강원도      춘천시  신사우동
# 2  201701    13    조치원읍  강원도      홍천군    서면
# 3  201701     3    조치원읍  경기도  고양시 덕양구   행주동
# 4  201701     1    조치원읍  경기도  고양시 덕양구  화정1동

# %%
plt.figure(figsize=(30,30))
sns.countplot(data=out_peo_df , x="전입시",hue="년월")
# Out:
# <AxesSubplot:xlabel='전입시', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
out_peo_df["전입시"].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대전광역시', '부산광역시', '서울특별시',
#        '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도', '충청남도',
#        '충청북도', '대구광역시'], dtype=object)

# %%
plt.figure(figsize=(30,30))
sns.countplot(data=come_peo_df , x="전출시",hue="년월")
# Out:
# <AxesSubplot:xlabel='전출시', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
come_peo_df["전출시"].unique()
# Out:
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라북도', '제주특별자치도', '충청남도',
#        '충청북도', '전라남도'], dtype=object)

# %%
age_bar_df = pd.read_csv("./22.세종시_연령별_인구현황.csv", encoding='cp949')

# %%
age_bar_df
# Out:
#         읍면동  201701_남자(총_거주자_수)  201701_남자(연령구간인구수)  201701_남자(0~9세)  \
# 0   세종특별자치시              121937              121937            17864
# 1      조치원읍               23529               23529             2525
# 2       연기면                1463                1463               56
# 3       연동면                1828                1828               87
# 4       부강면                3554                3554              235
# 5       금남면                5033                5033              263
# 6       장군면                3427                3427              132
# 7       연서면                4182                4182              222
# 8       전의면                3312                3312              194
# 9       전동면                2124                2124               67
# 10      소정면                1464                1464               89
# 11      한솔동               17376               17376             3185
# 12      새롬동                   0                   0                0
# ...

# %%
import numpy as np

# %%
a =age_bar_df.T
a
# Out:
#   File "<ipython-input-33-c08c34c815f4>", line 2
#     a
#     ^
# IndentationError: unexpected indent

# %%
plt.figure(figsize=(30,30))
plt.bar(age_bar_df["201701_남자(총_거주자_수)"],age_bar_df["읍면동"])
# Out:
# <BarContainer object of 21 artists>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
asd = pd.read_csv('./28.세종시_지역별_세대원수별_세대수.csv',encoding="cp949")

# %%
asd.head()
# Out:
#      읍면동      계    1인    2인    3인    4인   5인   6인  7인  8인  9인  10인이상
# 0   조치원읍  19472  8295  4165  3042  2729  944  220  63   9   4      1
# 1  연 기 면   1445   855   299   133   101   36   11   7   1   2      0
# 2  연 동 면   1680   834   461   206   114   44   14   5   1   0      1
# 3  부 강 면   3249  1603   821   420   273   93   34   3   0   0      2
# 4  금 남 면   4509  2128  1283   589   328  122   41  12   6   0      0

# %%
asd
# Out:
#       읍면동      계    1인    2인    3인    4인    5인   6인  7인  8인  9인  10인이상
# 0    조치원읍  19472  8295  4165  3042  2729   944  220  63   9   4      1
# 1   연 기 면   1445   855   299   133   101    36   11   7   1   2      0
# 2   연 동 면   1680   834   461   206   114    44   14   5   1   0      1
# 3   부 강 면   3249  1603   821   420   273    93   34   3   0   0      2
# 4   금 남 면   4509  2128  1283   589   328   122   41  12   6   0      0
# 5   장 군 면   3453  1956   806   332   200   106   35  11   6   1      0
# 6   연 서 면   3834  1863  1022   484   276   129   38  16   3   2      1
# 7   전 의 면   3045  1551   753   352   244   107   29   8   0   1      0
# 8   전 동 면   2130  1224   491   213   124    57   15   6   0   0      0
# 9   소 정 면   1231   565   308   160   127    58    9   1   2   1      0
# 10  한 솔 동   6333  1069  1134  1468  1944   584  101  25   5   1      2
# 11  새 롬 동  20495  6019  3980  4283  4754  1201  201  39  12   4      2
# ...

# %%
sns.barplot(data=asd, x="읍면동",y="2인")
# Out:
# <AxesSubplot:xlabel='읍면동', ylabel='2인'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 52824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51021 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
asdff = pd.read_csv("./29.세종시_거주의사(향후).csv",encoding="cp949")

# %%
asdff
# Out:
#         중분류           소분류  매우 그런편임  어느정도 그런편임    보통  약간 그렇지 않은편임  전혀 그렇지 않은편임
# 0        전체            소계     25.5       37.3  23.3         10.2          3.8
# 1    읍·면·동별          조치원읍     25.9       31.9  23.2         14.1          4.9
# 2    읍·면·동별           면지역     40.8       28.4  17.3          8.7          4.8
# 3    읍·면·동별           동지역     21.2       41.0  24.9          9.7          3.2
# 4        성별            남자     25.7       37.8  22.8          9.3          4.4
# 5        성별            여자     25.2       36.7  23.8         11.1          3.1
# 6     거주기간별          출범이전     41.0       30.5  18.8          7.3          2.4
# 7     거주기간별          출범이후     19.0       40.1  25.2         11.4          4.3
# 8       연령별        13~19세      7.4       39.1  33.4         14.1          5.9
# 9       연령별        20~29세     13.7       39.5  28.1         12.0          6.8
# 10      연령별        30~39세     20.1       40.2  24.9         12.2          2.6
# ...

# %%
apart_jeonsae_df.head()
# Out:
#      계약년월  계약일               시군구    본번  부번                  단지명 전월세구분  \
# 0  201701    1       세종특별자치시 고운동  1409   0    가락마을11단지(중흥에듀카운티)    전세
# 1  201701    1  세종특별자치시 조치원읍 신안리    35   3                  유니빌    전세
# 2  201701    2       세종특별자치시 고운동  1728   0  가락마을6단지(중흥S클래스프라디움)    전세
# 3  201701    2       세종특별자치시 고운동  1728   0  가락마을6단지(중흥S클래스프라디움)    전세
# 4  201701    2       세종특별자치시 고운동  1728   0  가락마을6단지(중흥S클래스프라디움)    전세
#
#    전용면적(㎡)  보증금(만원)  월세(만원)   층  건축년도
# 0  59.9907    16000       0  12  2016
# 1  28.1680     2800       0   6  2002
# 2  59.9942    19475       0  27  2015
# 3  59.7236    19475       0  21  2015
# 4  59.7236    17370       0   2  2015

# %%
apart_jeonsae_df["시군구"].unique()
# Out:
# array(['세종특별자치시 고운동', '세종특별자치시 조치원읍 신안리', '세종특별자치시 도담동', '세종특별자치시 보람동',
#        '세종특별자치시 소담동', '세종특별자치시 아름동', '세종특별자치시 어진동', '세종특별자치시 연서면 봉암리',
#        '세종특별자치시 종촌동', '세종특별자치시 한솔동', '세종특별자치시 조치원읍 신흥리',
#        '세종특별자치시 조치원읍 죽림리', '세종특별자치시 금남면 용포리', '세종특별자치시 나성동',
#        '세종특별자치시 연동면 명학리', '세종특별자치시 새롬동', '세종특별자치시 조치원읍 번암리',
#        '세종특별자치시 조치원읍 침산리', '세종특별자치시 조치원읍 상리', '세종특별자치시 조치원읍 교리',
#        '세종특별자치시 전의면 유천리', '세종특별자치시 부강면 부강리', '세종특별자치시 조치원읍 남리',
#        '세종특별자치시 전의면 동교리', '세종특별자치시 조치원읍 정리', '세종특별자치시 반곡동',
#        '세종특별자치시 전동면 노장리', '세종특별자치시 다정동', '세종특별자치시 대평동', '세종특별자치시 조치원읍 원리',
#        '세종특별자치시 장군면 금암리', '세종특별자치시 소정면 운당리', '세종특별자치시 조치원읍 서창리',
#        '세종특별자치시 해밀동'], dtype=object)

# %%
plt.figure(figsize=(30,30))
sns.countplot(data=apart_jeonsae_df, x="시군구")
# Out:
# <AxesSubplot:xlabel='시군구', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
plt.figure(figsize=(30,30))
sns.countplot(data=apart_jeonsae_df, x="전월세구분", hue="계약년월")
# Out:
# <AxesSubplot:xlabel='전월세구분', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
apart_deal_df
# Out:
#          계약년월  계약일               시군구    본번  부번                단지명   전용면적(㎡)  \
# 0      201701    1       세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)   16.9849
# 1      201701    1       세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)   59.8652
# 2      201701    2       세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)   84.9894
# 3      201701    2       세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)   84.9800
# 4      201701    2       세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티   84.9280
# ...       ...  ...               ...   ...  ..                ...       ...
# 21135  202010   27  세종특별자치시 조치원읍 신흥리   399   0    조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리    89   0              욱일아파트   84.9900
# 21137  202010   28       세종특별자치시 도담동   639   0    도램마을17단지(모아미래도)   84.9690
# 21138  202010   28   세종특별자치시 부강면 부강리   401  48                 주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리   396   0            조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도
# 0          8600   7  2016
# ...

# %%
plt.figure(figsize=(30,30))
sns.countplot(data=apart_deal_df, x="시군구")
# Out:
# <AxesSubplot:xlabel='시군구', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 49464 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 51333 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 53945 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 48324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
apart_deal_df['시군구'].unique()
# Out:
# array(['세종특별자치시 보람동', '세종특별자치시 종촌동', '세종특별자치시 고운동', '세종특별자치시 아름동',
#        '세종특별자치시 어진동', '세종특별자치시 연서면 봉암리', '세종특별자치시 조치원읍 신안리',
#        '세종특별자치시 조치원읍 신흥리', '세종특별자치시 조치원읍 죽림리', '세종특별자치시 한솔동',
#        '세종특별자치시 도담동', '세종특별자치시 연동면 명학리', '세종특별자치시 장군면 금암리', '세종특별자치시 나성동',
#        '세종특별자치시 조치원읍 남리', '세종특별자치시 부강면 부강리', '세종특별자치시 조치원읍 침산리',
#        '세종특별자치시 소담동', '세종특별자치시 조치원읍 번암리', '세종특별자치시 금남면 용포리',
#        '세종특별자치시 전의면 동교리', '세종특별자치시 조치원읍 서창리', '세종특별자치시 전동면 노장리',
#        '세종특별자치시 조치원읍 교리', '세종특별자치시 전의면 유천리', '세종특별자치시 소정면 운당리',
#        '세종특별자치시 새롬동', '세종특별자치시 조치원읍 정리', '세종특별자치시 다정동', '세종특별자치시 대평동',
#        '세종특별자치시 반곡동', '세종특별자치시 조치원읍 원리'], dtype=object)

# %%
plt.figure(figsize=(30,30))
sns.countplot(data=apart_deal_df, x="계약년월")
# Out:
# <AxesSubplot:xlabel='계약년월', ylabel='count'>
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 44228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50557 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/patricklee/opt/anaconda3/envs/tensorflow/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 50900 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
